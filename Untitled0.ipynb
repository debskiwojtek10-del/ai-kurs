# %% [markdown]
# <a href="https://colab.research.google.com/github/debskiwojtek10-del/ai-kurs/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# bomboclat

# %%
num=3
print(num)

# %%
num = 10
float_num = 5.50
text = "hello"
bool_variable = False
print(text)
print(f'cena bananow jest rowna {float_num}')
games = [" risk of rain2" , "cs" , "minecraft"]
print(games[0])
games.append("fortnite")
print(games)
# Out:
# hello
# cena bananow jest rowna 5.5
#  risk of rain2
# [' risk of rain2', 'cs', 'minecraft', 'fortnite']

# %%
print(int("fff", 20))
# Out:
# 6315

# %%
temperature = float(input("podaj temp: "))
if temperature <20:
  print("podwyzszam temp")
elif temperature > 22:
    print("wylaczam sie")
else:
    print("temperatura w normie")
# Out:
# podaj temp: 30
# wylaczam sie

# %%
for game in games:
  print(game)

for i in range(0,5):
  print(i)

for i in range(-8,19,3):
  print(i)
  def add(a, b):
    print(a+b)
    add(a=1, b=1)
# Out:
#  risk of rain2
# cs
# minecraft
# fortnite
# 0
# 1
# 2
# 3
# 4
# -8
# -5
# -2
# 1
# 4
# 7
# 10
# 13
# 16
